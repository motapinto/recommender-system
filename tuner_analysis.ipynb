# %%
import os
from Utils.DataIO import DataIO

models = ['ItemKNNCF', 'UserKNNCF', 'RP3beta', 'P3alpha', 'P3alpha']
model_name = models[2]
output_folder_path = os.path.join('Recommenders', 'tuner_results'+os.sep)

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(model_name + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#     topK     alpha      beta normalize_similarity
# 0    538  0.151993  1.257042                False
# 1    811  1.904045  1.260053                False
# 2    939  0.253888  1.444592                 True
# 3    334   0.84271  1.337293                False
# 4    936  0.910958  0.407868                False
# 5     96  1.585973  0.299862                 True
# 6    672  0.741024  1.812747                 True
# 7    154  1.150538  0.737531                False
# 8    864  1.527397  0.454823                False
# 9    939  0.916422  0.405859                False
# 10   920  0.733339   0.40332                False
# 11   826  0.814542  1.760429                False
# 12   681  0.806485   0.25336                 True
# 13  1000  0.805492   0.18825                False
# 14     5  1.831658       0.0                 True
# 15   476  0.554868       0.0                False
# 16   956  0.580266       0.0                 True
# 17     5  0.223313       0.0                 True
# ...

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#           ROC_AUC PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP  \
#    cutoff
# 0  10         0.0  0.000396                 0.000405  0.000082  0.000129
# 1  10         0.0  0.000359                 0.000372  0.000098  0.000095
# 2  10         0.0  0.000638                 0.000645  0.000117  0.000187
# 3  10         0.0  0.000931                 0.000944  0.000194  0.000312
# 4  10         0.0  0.212505                 0.213893  0.046374  0.101107
# 5  10         0.0  0.156575                 0.157603  0.034482   0.06849
# 6  10         0.0  0.000308                 0.000315  0.000072  0.000131
# 7  10         0.0  0.006938                 0.006953  0.001642  0.001591
# 8  10         0.0  0.003608                 0.003665  0.000918  0.000833
# 9  10         0.0   0.21125                 0.212611   0.04597  0.099819
# 10 10         0.0  0.217074                 0.218749  0.047867  0.106471
# 11 10         0.0  0.000491                 0.000504  0.000123   0.00019
# ...

# %%
result_best_on_test = search_metadata["result_on_last"]
result_best_on_test
# Out:
#        ROC_AUC PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP  \
# cutoff
# 10         0.0  0.364108                 0.365071  0.061938  0.222356
#
#        MAP_MIN_DEN       MRR      NDCG        F1  HIT_RATE  ...  \
# cutoff                                                      ...
# 10        0.222775  0.620277  0.380507  0.105867  0.954695  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.049504      0.999341              0.954066
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010134        7.400399                   0.988214
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040887              0.597306                 2.844691
#
#        RATIO_NOVELTY
# cutoff
# 10          0.026187
#
# [1 rows x 26 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 563,
#  'alpha': 1.0286569648922121,
#  'beta': 0.6926379776833416,
#  'normalize_similarity': True}

# %%
time_df = search_metadata["time_df"]
time_df
# Out:
#         train validation       test
# 0   25.225993  14.558997  14.540884
# 1   29.821354  15.401335        NaN
# 2   31.616637  16.558289   16.48762
# 3   22.595968   9.543297   9.704084
# 4   31.248998  13.530538  13.753209
# 5   19.193877   8.044827        NaN
# 6   27.480275  13.448854        NaN
# 7   20.395253  10.217973        NaN
# 8   30.401751  12.627121        NaN
# 9   30.753678    13.4054        NaN
# 10  30.713606  16.078339  15.907537
# 11  29.671337  13.909837        NaN
# 12  26.993885  10.855987        NaN
# 13  31.133022  14.200383        NaN
# 14  17.369161   6.585752        NaN
# 15  23.599979  10.463269        NaN
# 16  29.872803  10.164597        NaN
# 17   17.44056   6.399981        NaN
# 18  17.203969    6.83948        NaN
# 19  21.430165   9.615028        NaN
# 20  23.660999  10.449449        NaN
# 21  17.408614   6.417944        NaN
# 22  31.745837  15.125906  15.086441
# 23   29.65768  12.095649        NaN
# 24  30.972921  14.255523        NaN
# ...

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
