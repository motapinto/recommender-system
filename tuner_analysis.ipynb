# %%
import os
from Utils.DataIO import DataIO

models = ['ItemKNNCFRecommender', 'UserKNNCFRecommender']
model_name = models[0]
output_folder_path = os.path.join('Recommenders', 'tuner_results'+os.sep)

data_loader = DataIO(folder_path=output_folder_path)
search_metadata = data_loader.load_data(model_name + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#    topK shrink similarity normalize feature_weighting URM_bias
# 0   960    164    jaccard     False            TF-IDF     True
# 1   650    157    pearson      True              none     True
# 2   107    830    pearson     False            TF-IDF    False
# 3   577    334  euclidean      True              BM25     True
# 4   271    708     cosine      True            TF-IDF     True
# 5   128    144    jaccard      True            TF-IDF    False
# 6   763    607     cosine      True              none    False
# 7   994    227     cosine      True              BM25    False
# 8    39   1000   tanimoto     False              BM25    False
# 9     5      0   tanimoto     False              none    False
# 10  358    996  euclidean      True              none    False
# 11  333    735   adjusted      True            TF-IDF     True
# 12  148    753  euclidean      True              BM25     True
# 13  367    369    pearson      True            TF-IDF    False
# 14  342    946   tanimoto      True              BM25    False
# 15  185    983   adjusted      True              none    False
# 16   66    725    jaccard     False            TF-IDF    False
# 17   50    593  euclidean     False            TF-IDF    False
# 18   32    806     cosine     False              none    False
# 19    7    984  euclidean     False            TF-IDF     True

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#           ROC_AUC PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP  \
#    cutoff
# 0  10         0.0  0.165558                  0.16902  0.055169  0.077023
# 1  10         0.0  0.001865                 0.001879  0.000516  0.000523
# 2  10         0.0  0.153029                 0.156019  0.050149  0.072039
# 3  10         0.0  0.069083                 0.069726  0.021009  0.026553
# 4  10         0.0  0.174671                 0.178766  0.059704  0.081874
# 5  10         0.0  0.170258                 0.174196  0.057926  0.079244
# 6  10         0.0  0.165484                 0.168875  0.054802   0.07818
# 7  10         0.0  0.168216                 0.171369  0.056531  0.076285
# 8  10         0.0  0.156576                 0.160161  0.053983  0.069659
# 9  10         0.0  0.147566                  0.15098  0.049877  0.064876
# 10 10         0.0  0.119461                 0.121813  0.038606  0.049836
# 11 10         0.0  0.151208                 0.154133  0.049082  0.071455
# 12 10         0.0  0.069854                  0.07098  0.021905  0.026713
# 13 10         0.0  0.168025                 0.171726   0.05658  0.078452
# 14 10         0.0  0.170787                 0.174369   0.05792  0.079086
# 15 10         0.0  0.001865                 0.001879  0.000516  0.000523
# 16 10         0.0  0.169119                 0.172928  0.057122  0.078192
# 17 10         0.0  0.184894                 0.189128  0.063426  0.086425
# 18 10         0.0  0.156723                 0.159816  0.051545  0.073699
# 19 10         0.0  0.182368                 0.186611  0.062378  0.084656
#
#           MAP_MIN_DEN       MRR      NDCG        F1  HIT_RATE  ...  \
#    cutoff                                                      ...
# 0  10        0.078606   0.38073   0.17739   0.08276  0.798193  ...
# 1  10        0.000526  0.005075  0.001815  0.000808  0.018213  ...
# 2  10        0.073414  0.373982  0.167059  0.075542  0.767937  ...
# 3  10        0.026756  0.179981   0.07223   0.03222  0.473893  ...
# 4  10        0.083819  0.397003  0.187306   0.08899  0.821253  ...
# 5  10        0.081128  0.387983  0.182329  0.086442  0.809503  ...
# 6  10        0.079759   0.38868  0.179005  0.082337  0.796431  ...
# 7  10        0.077538  0.368263  0.176279  0.084624  0.796211  ...
# 8  10        0.071145  0.353706   0.16511  0.080285  0.778732  ...
# 9  10        0.066353  0.344415   0.15656  0.074555  0.764779  ...
# 10 10        0.050933  0.281951  0.125091  0.058354   0.67379  ...
# 11 10        0.072789   0.37198  0.165491  0.074108  0.758904  ...
# 12 10        0.027097  0.180137  0.072965  0.033352  0.476023  ...
# 13 10        0.080097  0.385784  0.180234  0.084654  0.803114  ...
# 14 10        0.080807  0.382902  0.181644  0.086503  0.805904  ...
# 15 10        0.000526  0.005075  0.001815  0.000808  0.018213  ...
# 16 10        0.080052   0.37986  0.180109    0.0854  0.803408  ...
# 17 10        0.088252  0.404959  0.196082  0.094452  0.843872  ...
# 18 10        0.075073   0.37653  0.170288  0.077575   0.77205  ...
# 19 10        0.086691  0.400445  0.193346   0.09296  0.839318  ...
#
#           COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
#    cutoff
# 0  10                  0.013013      0.997582              0.796264
# 1  10                  0.004208      0.997582              0.018168
# 2  10                  0.003932      0.997582              0.766081
# 3  10                  0.216623      0.997582              0.472747
# 4  10                  0.020433      0.997582              0.819267
# 5  10                  0.019326      0.997582              0.807546
# 6  10                   0.00958      0.997582              0.794505
# 7  10                  0.064012      0.997582              0.794286
# 8  10                  0.062683      0.997582               0.77685
# 9  10                  0.028739      0.997582               0.76293
# 10 10                  0.059693      0.997582              0.672161
# 11 10                  0.003765      0.997582               0.75707
# 12 10                  0.219835      0.997582              0.474872
# 13 10                  0.009469      0.997582              0.801172
# 14 10                  0.027853      0.997582              0.803956
# 15 10                  0.004208      0.997582              0.018168
# 16 10                  0.016501      0.997582              0.801465
# 17 10                  0.014287      0.997582              0.841832
# 18 10                  0.005482      0.997582              0.770183
# 19 10                  0.026967      0.997582              0.837289
#
#           DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
#    cutoff
# 0  10           0.002308         5.71494                   0.975001
# 1  10           0.005895        7.112151                   0.991755
# 2  10           0.001471        5.002278                   0.964297
# 3  10           0.209743         12.2846                   1.000104
# 4  10           0.003479        6.250717                   0.980014
# 5  10            0.00304        6.022071                   0.977525
# 6  10           0.001886         5.43379                   0.970929
# 7  10           0.017418        8.545061                   0.995291
# 8  10           0.019855        8.805534                   0.996248
# 9  10           0.006808        7.268396                   0.989643
# 10 10           0.019839         8.81593                   0.996926
# 11 10           0.001398        4.920534                   0.962538
# 12 10           0.214542       12.333399                   1.000119
# 13 10           0.002081        5.595435                   0.973669
# 14 10           0.006239        7.098292                   0.987636
# 15 10           0.005895        7.112151                   0.991755
# 16 10           0.003147        6.139409                   0.979934
# 17 10            0.00332        6.229474                   0.979532
# 18 10           0.001845         5.36939                   0.970772
# 19 10           0.009372        7.604423                    0.99107
#
#           RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
#    cutoff
# 0  10                 0.009308               0.46123                 3.394678
# 1  10                 0.023771              0.573994                 0.104491
# 2  10                 0.005932              0.403714                 3.649464
# 3  10                 0.845833              0.991441                 0.352757
# 4  10                 0.014031              0.504471                   3.2836
# 5  10                  0.01226              0.486018                 3.376477
# 6  10                 0.007604               0.43854                 3.551872
# 7  10                 0.070242              0.689638                 2.092058
# 8  10                 0.080071               0.71066                 1.838502
# 9  10                 0.027455              0.586603                 2.951525
# 10 10                 0.080005              0.711499                 1.790067
# 11 10                 0.005637              0.397117                 3.667496
# 12 10                 0.865185               0.99538                 0.303735
# 13 10                 0.008394              0.451585                 3.500118
# 14 10                 0.025159              0.572875                 2.733259
# 15 10                 0.023771              0.573994                 0.104491
# 16 10                 0.012691              0.495487                 3.359819
# 17 10                  0.01339              0.502756                 3.272132
# 18 10                  0.00744              0.433342                 3.576804
# 19 10                 0.037794              0.613723                 2.688355
#
#           RATIO_NOVELTY
#    cutoff
# 0  10          0.024672
# 1  10          0.042398
# 2  10          0.024305
# 3  10          0.034631
# 4  10          0.024924
# 5  10          0.024739
# 6  10          0.024439
# 7  10          0.027805
# 8  10          0.028395
# 9  10          0.025381
# 10 10           0.02755
# 11 10          0.024275
# 12 10          0.035158
# 13 10          0.024497
# 14 10          0.026236
# 15 10          0.042398
# 16 10          0.024705
# 17 10           0.02499
# 18 10          0.024399
# 19 10          0.026223
#
# [20 rows x 26 columns]

# %%
result_best_on_test = search_metadata["result_on_last"]
result_best_on_test

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 50,
#  'shrink': 593,
#  'similarity': 'euclidean',
#  'normalize': False,
#  'feature_weighting': 'TF-IDF',
#  'URM_bias': False}

# %%
time_df = search_metadata["time_df"]
time_df
# Out:
#         train validation       test
# 0   55.339112  31.589697  31.414333
# 1   43.411795   7.127187        NaN
# 2   45.772306  26.982715        NaN
# 3   53.683887  25.859673        NaN
# 4   49.875628  25.285064  25.048679
# 5   45.132724  15.243629        NaN
# 6   52.796924   55.91812        NaN
# 7    56.35862  39.393317        NaN
# 8   51.684584  13.470555        NaN
# 9   44.334498   8.652562        NaN
# 10  51.567538  16.743402        NaN
# 11  47.489134   41.80382        NaN
# 12   48.55848  15.744237        NaN
# 13  48.224306   42.08577        NaN
# 14  48.079338  26.774177        NaN
# 15  41.862952   7.123534        NaN
# 16  48.057069  14.749891        NaN
# 17  45.560446   7.756803   7.840055
# 18  44.009742  18.735959        NaN
# 19  47.438401   7.695881        NaN

# %%
exception_list = search_metadata["exception_list"]
exception_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
